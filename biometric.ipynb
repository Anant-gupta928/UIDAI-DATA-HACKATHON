# %%
import pandas as pd

# %%
files = [
    "bio1.csv",
    "bio2.csv",
    "bio3.csv",
    "bio4.csv"
]

df = pd.concat(
    [pd.read_csv(f) for f in files],
    ignore_index=True
)

df.to_csv("bio_merged.csv", index=False)

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1861108 entries, 0 to 1861107
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_age_5_17  int64
#  5   bio_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 85.2+ MB

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, explorative=True)
profile.to_file("demo_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                     | 0/6 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 6/6 [00:01<00:00,  3.88it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df[df.duplicated(keep=False)].sort_values(
    ["date", "state", "district", "pincode"]
)
# Out:
#                date             state                 district  pincode  \
# 1480030  01-09-2025             Assam                 Sonitpur   784174
# 1481176  01-09-2025             Assam                 Sonitpur   784174
# 1480031  01-09-2025             Assam                 Sonitpur   784182
# 1481177  01-09-2025             Assam                 Sonitpur   784182
# 1480032  01-09-2025             Assam  South Salmara Mankachar   783127
# ...             ...               ...                      ...      ...
# 352842   31-10-2025  Himachal Pradesh                    Mandi   175038
# 349533   31-10-2025  Himachal Pradesh                    Mandi   175039
# 352843   31-10-2025  Himachal Pradesh                    Mandi   175039
# 349534   31-10-2025  Himachal Pradesh                    Mandi   175046
# 352844   31-10-2025  Himachal Pradesh                    Mandi   175046
#
#          bio_age_5_17  bio_age_17_
# 1480030             0            1
# 1481176             0            1
# 1480031             4            4
# 1481177             4            4
# 1480032             3            3
# ...               ...          ...
# 352842              6            4
# 349533              1            0
# 352843              1            0
# 349534              6            0
# 352844              6            0
#
# [189792 rows x 6 columns]

# %%
rows_before = df.shape[0]
print(rows_before)
# Out:
# 1861108

# %%
df_clean= df.drop_duplicates(
    subset=['date', 'pincode', 'bio_age_5_17', 'bio_age_17_'],
    keep='first'
)

# %%
rows_after = df_clean.shape[0]

# %%
rows_removed = rows_before - rows_after
percent_removed = (rows_removed / rows_before) * 100

print("Rows before :", rows_before)
print("Rows after  :", rows_after)
print("Rows removed:", rows_removed)
print(f"Decrease %  : {percent_removed:.2f}%")
# Out:
# Rows before : 1861108
# Rows after  : 1754015
# Rows removed: 107093
# Decrease %  : 5.75%

# %%
df_clean[(df_clean["pincode"] == 784174) & (df_clean["date"] == "01-09-2025")]
# Out:
#                date  state   district  pincode  bio_age_5_17  bio_age_17_
# 1480030  01-09-2025  Assam   Sonitpur   784174             0            1
# 1487773  01-09-2025  Assam  Biswanath   784174             3            3

# %%
df_clean = df_clean.reset_index(drop=True)

# %%
print("Duplicate rows:", df_clean.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print("unique Raw states:", df_clean['state'].nunique())
# Out:
# unique Raw states: 57

# %%
print(df_clean["state"].unique())
# Out:
# ['Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir'
#  'Jammu and Kashmir' 'Jharkhand' 'Karnataka' 'Kerala'
#  'Andaman & Nicobar Islands' 'Andaman and Nicobar Islands'
#  'Andhra Pradesh' 'Mizoram' 'Nagaland' 'Odisha' 'Orissa' 'Pondicherry'
#  'Puducherry' 'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana'
#  'Tripura' 'Uttar Pradesh' 'Uttarakhand' 'West Bengal' 'Ladakh'
#  'Lakshadweep' 'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya'
#  'Arunachal Pradesh' 'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh'
#  'Dadra and Nagar Haveli' 'Daman & Diu' 'Delhi' 'Daman and Diu'
#  'West  Bengal' 'Dadra and Nagar Haveli and Daman and Diu'
#  'Dadra & Nagar Haveli' 'West bengal' 'West Bangal' 'ODISHA' 'WEST BENGAL'
#  'andhra pradesh' 'odisha' 'Westbengal' 'WESTBENGAL' 'Chhatisgarh'
#  'Tamilnadu' 'Uttaranchal' 'west Bengal']

# %%
df_clean["state_clean"] = df_clean["state"].str.lower().str.strip()
print(sorted(df_clean["state_clean"].unique()))
# Out:
# ['andaman & nicobar islands', 'andaman and nicobar islands', 'andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'chandigarh', 'chhatisgarh', 'chhattisgarh', 'dadra & nagar haveli', 'dadra and nagar haveli', 'dadra and nagar haveli and daman and diu', 'daman & diu', 'daman and diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh', 'jammu & kashmir', 'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'orissa', 'pondicherry', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu', 'tamilnadu', 'telangana', 'tripura', 'uttar pradesh', 'uttarakhand', 'uttaranchal', 'west  bengal', 'west bangal', 'west bengal', 'westbengal']

# %%
fix_map = {
    "orissa": "odisha",
    "pondicherry": "puducherry",
    'chhatisgarh': 'chhattisgarh',
    'balanagar': 'telangana',
    'puttenahalli':'karnataka',
    'raja annamalai puram':'tamil nadu',
    'darbhanga': 'bihar',
    'madanapalle':'andhra pradesh',
    'nagpur':'madhya pradesh',
    
    'west bengli': "west bengal",
    "west bangal": "west bengal",
    "westbengal": "west bengal",
    "west  bengal": "west bengal",
    'uttaranchal':'uttarakhand',
    'jaipur':'rajasthan',

    "jammu & kashmir": "jammu and kashmir",
    'tamilnadu':'tamil nadu',

    "andaman & nicobar islands": "andaman and nicobar islands",

    "dadra & nagar haveli": "dadra and nagar haveli and daman and diu",
    "daman and diu": "dadra and nagar haveli and daman and diu",
    "daman & diu": "dadra and nagar haveli and daman and diu",
    "dadra and nagar haveli": "dadra and nagar haveli and daman and diu",
    "100000": None
}
df_clean["state_clean"] = df_clean["state_clean"].replace(fix_map)
df_clean = df_clean[df_clean["state_clean"].notna()]
print("\nSTEP-2.4 Final Clean Result:")
print("Final Clean States & UTs:", df_clean["state_clean"].nunique())
print(sorted(df_clean["state_clean"].unique()))
# Out:
# STEP-2.4 Final Clean Result:
# Final Clean States & UTs: 36
# ['andaman and nicobar islands', 'andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra and nagar haveli and daman and diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu', 'telangana', 'tripura', 'uttar pradesh', 'uttarakhand', 'west bengal']

# %%
df_clean.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_ state_clean
# 0  19-09-2025   Goa  North Goa   403502             0            4         goa
# 1  19-09-2025   Goa  North Goa   403508             1            4         goa
# 2  19-09-2025   Goa  North Goa   403513             2            0         goa
# 3  19-09-2025   Goa  North Goa   403527             2            2         goa
# 4  19-09-2025   Goa  South Goa   403601             7            3         goa

# %%
df_clean['state_clean'] = df_clean['state_clean'].astype(str).str.strip().str.title()
df_clean.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_ state_clean
# 0  19-09-2025   Goa  North Goa   403502             0            4         Goa
# 1  19-09-2025   Goa  North Goa   403508             1            4         Goa
# 2  19-09-2025   Goa  North Goa   403513             2            0         Goa
# 3  19-09-2025   Goa  North Goa   403527             2            2         Goa
# 4  19-09-2025   Goa  South Goa   403601             7            3         Goa

# %%
df_clean.drop(columns=['state'])
# Out:
#                date    district  pincode  bio_age_5_17  bio_age_17_  \
# 0        19-09-2025   North Goa   403502             0            4
# 1        19-09-2025   North Goa   403508             1            4
# 2        19-09-2025   North Goa   403513             2            0
# 3        19-09-2025   North Goa   403527             2            2
# 4        19-09-2025   South Goa   403601             7            3
# ...             ...         ...      ...           ...          ...
# 1754010  19-09-2025  West Delhi   110041           102          100
# 1754011  19-09-2025  West Delhi   110043             8            5
# 1754012  19-09-2025  West Delhi   110058             7            5
# 1754013  19-09-2025   North Goa   403102             1            0
# 1754014  19-09-2025   North Goa   403106             1            0
#
#         state_clean
# 0               Goa
# 1               Goa
# 2               Goa
# 3               Goa
# 4               Goa
# ...             ...
# 1754010       Delhi
# 1754011       Delhi
# 1754012       Delhi
# 1754013         Goa
# 1754014         Goa
#
# [1754015 rows x 6 columns]

# %%
dup_pincode_rows = df_clean[
    df_clean.duplicated(subset=['pincode', 'date'], keep=False)
].sort_values(['pincode', 'date'])

dup_pincode_rows
# Out:
#                date  state         district  pincode  bio_age_5_17  \
# 1268156  01-03-2025  Delhi        New Delhi   110001           181
# 1269660  01-03-2025  Delhi    Central Delhi   110001            10
# 1377423  01-09-2025  Delhi        New Delhi   110001             6
# 1382001  01-09-2025  Delhi    Central Delhi   110001             0
# 338609   01-11-2025  Delhi        New Delhi   110001             1
# ...             ...    ...              ...      ...           ...
# 223755   26-10-2025  Bihar       Kishanganj   855117            63
# 317478   31-10-2025  Bihar          Katihar   855117             0
# 317489   31-10-2025  Bihar       Kishanganj   855117            39
# 891204   11-11-2025  Bihar  Purba Champaran   855456             0
# 901946   11-11-2025  Bihar   East Champaran   855456             0
#
#          bio_age_17_ state_clean
# 1268156          159       Delhi
# 1269660           88       Delhi
# 1377423            4       Delhi
# 1382001            2       Delhi
# 338609             5       Delhi
# ...              ...         ...
# 223755            89       Bihar
# 317478             1       Bihar
# 317489           166       Bihar
# 891204             1       Bihar
# 901946             3       Bihar
#
# [637708 rows x 7 columns]

# %%
df_clean[(df_clean["pincode"] == 784174) & (df_clean["date"] == "01-09-2025")]
# Out:
#                date  state   district  pincode  bio_age_5_17  bio_age_17_  \
# 1386266  01-09-2025  Assam   Sonitpur   784174             0            1
# 1393441  01-09-2025  Assam  Biswanath   784174             3            3
#
#         state_clean
# 1386266       Assam
# 1393441       Assam

# %%
df_agg = (
    df_clean
    .groupby(['date', 'pincode'], as_index=False)
    .agg({
        'state_clean': lambda x: x.mode().iloc[0],
        'district': lambda x: x.mode().iloc[0],
        'bio_age_5_17': 'sum',
        'bio_age_17_': 'sum'
    })
)

# %%
df_agg[(df_agg["pincode"] == 784174) & (df_agg["date"] == "01-09-2025")]
# Out:
#               date  pincode state_clean   district  bio_age_5_17  bio_age_17_
# 106613  01-09-2025   784174       Assam  Biswanath             3            4

# %%
dup_pincode_rows = df_agg[
    df_agg.duplicated(subset=['pincode', 'date'], keep=False)
].sort_values(['pincode', 'date'])

dup_pincode_rows
# Out:
# Empty DataFrame
# Columns: [date, pincode, state_clean, district, bio_age_5_17, bio_age_17_]
# Index: []

# %%
df_agg[(df_agg["pincode"] == 784174) & (df_agg["date"] == "01-09-2025")]
# Out:
#               date  pincode state_clean   district  bio_age_5_17  bio_age_17_
# 106613  01-09-2025   784174       Assam  Biswanath             3            4

# %%
df_agg['date'] = pd.to_datetime(
    df_agg['date'],
    format='%d-%m-%Y'
)

# %%
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408962 entries, 0 to 1408961
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   date          1408962 non-null  datetime64[ns]
#  1   pincode       1408962 non-null  int64
#  2   state_clean   1408962 non-null  object
#  3   district      1408962 non-null  object
#  4   bio_age_5_17  1408962 non-null  int64
#  5   bio_age_17_   1408962 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 64.5+ MB

# %%
df_agg['date_month']= df_agg['date'].dt.month_name()
df_agg.sample(5)
# Out:
#               date  pincode    state_clean   district  bio_age_5_17  \
# 728198  2025-11-13   758022         Odisha  Kendujhar             6
# 1195361 2025-10-25   431516    Maharashtra   Parbhani             3
# 605938  2025-11-11   227101  Uttar Pradesh    Lucknow             3
# 831964  2025-11-15   638111     Tamil Nadu   Tiruppur            18
# 1381500 2025-10-30   500057      Telangana  Hyderabad             2
#
#          bio_age_17_ date_month
# 728198             6   November
# 1195361            6    October
# 605938             6   November
# 831964            16   November
# 1381500            1    October

# %%
df_agg['date_day_name']= df_agg['date'].dt.day_name()
df_agg.head(5)
# Out:
#         date  pincode state_clean       district  bio_age_5_17  bio_age_17_  \
# 0 2025-03-01   110001       Delhi  Central Delhi           191          247
# 1 2025-03-01   110002       Delhi  Central Delhi           260          427
# 2 2025-03-01   110003       Delhi  Central Delhi           347          411
# 3 2025-03-01   110005       Delhi  Central Delhi           441          950
# 4 2025-03-01   110006       Delhi    North Delhi           901         1526
#
#   date_month date_day_name
# 0      March      Saturday
# 1      March      Saturday
# 2      March      Saturday
# 3      March      Saturday
# 4      March      Saturday

# %%
df_agg['quater']= df_agg['date'].dt.quarter
df_agg.sample(5)
# Out:
#              date  pincode        state_clean    district  bio_age_5_17  \
# 550574 2025-09-10   798615           Nagaland  Mokokchung             0
# 345234 2025-09-06   271319      Uttar Pradesh       Gonda             3
# 922883 2025-12-16   827006          Jharkhand      Bokaro             3
# 423381 2025-12-07   563120          Karnataka       Kolar             3
# 194580 2025-09-03   185152  Jammu And Kashmir     Rajouri             0
#
#         bio_age_17_ date_month date_day_name  quater
# 550574            1  September     Wednesday       3
# 345234            0  September      Saturday       3
# 922883            1   December       Tuesday       4
# 423381            0   December        Sunday       4
# 194580            3  September     Wednesday       3

# %%
df_agg[(df_agg["pincode"] == 784174) & (df_agg["date"] == "2025-09-01")]
# Out:
#              date  pincode state_clean   district  bio_age_5_17  bio_age_17_  \
# 106613 2025-09-01   784174       Assam  Biswanath             3            4
#
#        date_month date_day_name  quater
# 106613  September        Monday       3

# %%
df_agg.to_csv("biometric.csv", index=False)

# %%
df_agg[(df_agg["pincode"] == 784174) & (df_agg["date"] == "2025-09-01")]
# Out:
#              date  pincode state_clean   district  bio_age_5_17  bio_age_17_  \
# 106613 2025-09-01   784174       Assam  Biswanath             3            4
#
#        date_month date_day_name  quater
# 106613  September        Monday       3

# %%
df_agg.head()
# Out:
#         date  pincode state_clean       district  bio_age_5_17  bio_age_17_  \
# 0 2025-03-01   110001       Delhi  Central Delhi           191          247
# 1 2025-03-01   110002       Delhi  Central Delhi           260          427
# 2 2025-03-01   110003       Delhi  Central Delhi           347          411
# 3 2025-03-01   110005       Delhi  Central Delhi           441          950
# 4 2025-03-01   110006       Delhi    North Delhi           901         1526
#
#   date_month date_day_name  quater
# 0      March      Saturday       1
# 1      March      Saturday       1
# 2      March      Saturday       1
# 3      March      Saturday       1
# 4      March      Saturday       1

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df_agg, explorative=True)
profile.to_file("biometric.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                     | 0/9 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 9/9 [00:01<00:00,  5.32it/s]
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/model/pandas/discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 9 9 9]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_agg[(df_agg["pincode"] == 784174) & (df_agg["date"] == "2025-09-01")]
# Out:
#              date  pincode state_clean   district  bio_age_5_17  bio_age_17_  \
# 106613 2025-09-01   784174       Assam  Biswanath             3            4
#
#        date_month date_day_name  quater
# 106613  September        Monday       3

# %%
df_new = pd.read_csv("biometric.csv")

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408962 entries, 0 to 1408961
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   date          1408962 non-null  object
#  1   pincode       1408962 non-null  int64
#  2   state_clean   1408962 non-null  object
#  3   district      1408962 non-null  object
#  4   bio_age_5_17  1408962 non-null  int64
#  5   bio_age_17_   1408962 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 64.5+ MB

# %%
df_new.head()
# Out:
#          date  pincode state_clean       district  bio_age_5_17  bio_age_17_
# 0  01-03-2025   110001       Delhi  Central Delhi           191          247
# 1  01-03-2025   110002       Delhi  Central Delhi           260          427
# 2  01-03-2025   110003       Delhi  Central Delhi           347          411
# 3  01-03-2025   110005       Delhi  Central Delhi           441          950
# 4  01-03-2025   110006       Delhi    North Delhi           901         1526

# %%
df_new[(df_new["pincode"] == 784174) & (df_new["date"] == "01-09-2025")]
# Out:
#               date  pincode state_clean   district  bio_age_5_17  bio_age_17_
# 106613  01-09-2025   784174       Assam  Biswanath             3            4
